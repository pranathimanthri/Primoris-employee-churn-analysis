# %%
import pandas as pd
import numpy as np

# %%
allEmp = pd.read_csv('/content/1.AllEmployees.csv')
newHires = pd.read_csv('/content/2. NewHires.csv')
promotions = pd.read_csv('/content/3.Promotions.csv')
demotions = pd.read_csv('/content/4.Demotions.csv')
rehires = pd.read_csv('/content/5. Rehires.csv')
transferIns = pd.read_csv('/content/6.TransferIn.csv')
transferOuts = pd.read_csv('/content/7. TransferOut.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d8731a49a01d> in <cell line: 0>()
# ----> 1 allEmp = pd.read_csv('/content/1.AllEmployees.csv')
#       2 newHires = pd.read_csv('/content/2. NewHires.csv')
#       3 promotions = pd.read_csv('/content/3.Promotions.csv')
#       4 demotions = pd.read_csv('/content/4.Demotions.csv')
#       5 rehires = pd.read_csv('/content/5. Rehires.csv')
#
# ...

# %%
allEmp.head(1)
# Out:
#     EE #           Job Title Current Employment Status  Project Code  \
# 0  82820  Laborer Renewables                         T         55086
#
#   Original Hire Date Last Hire Date LOS in Days Termination Date Reason Code  \
# 0         01/11/2023     01/11/2023          97       04/18/2023   Other Job
#
#    Left  Fired
# 0     1      0

# %%
newHires.head(1)
# Out:
#      EE # FLSA Category  PR Dept    HireDate    Reason Craft Class Code  \
# 0  234223    Non-Exempt     3000  08/18/2016  New hire              NaN
#
#    Project Code
# 0           NaN

# %%
promotions.head(1)
# Out:
#      EE # FLSA Category  PR Dept     Reason Craft Class Code  Project Code  \
# 0  274636    Non-Exempt     4101  Promotion        18-6-A624           NaN
#
#   Promotion Date
# 0     2022-08-08

# %%
demotions.head(1)
# Out:
#      EE # FLSA Category  PR Dept  Project Code Craft Class Code    Reason  \
# 0  319521    Non-Exempt     4104         55301       18-708-500  Demotion
#
#   DemotionDate
# 0     5/6/2024

# %%
rehires.head(1)
# Out:
#      EE # FLSA Category  PR Dept PR Dept Desc.            Craft Class Desc  \
# 0  276537        Exempt     4101    Management  MANAGER/OPERATIONS MANAGER
#
#   Craft Class Code  Project Code Project  RehireDate  Reason    Audit Date
# 0        18-1-S171           NaN     NaN  05/23/2022  Rehire  May 26, 2022

# %%
rehires = rehires.drop(['PR Dept Desc.', 'Project', 'Craft Class Desc', 'Audit Date'], axis=1)

# %%
rehires.head()
# Out:
#      EE # FLSA Category  PR Dept Craft Class Code  Project Code  RehireDate  \
# 0  276537        Exempt     4101        18-1-S171           NaN  05/23/2022
# 1  317687    Non-Exempt     4104        18-47-500       55109.0  05/29/2024
# 2  312623    Non-Exempt     4104       18-708-500       55301.0  02/07/2024
# 3  312623    Non-Exempt     4104       18-708-500       55301.0  04/09/2024
# 4  286358    Non-Exempt     4104       18-73-1000       55101.0  06/26/2023
#
#    Reason
# 0  Rehire
# 1  Rehire
# 2  Rehire
# 3  Rehire
# 4  Rehire

# %%
transferIns.head(1)
# Out:
#      ee_# flsa_category  pr_dept craft_class_code project_code effective_date  \
# 0  291822    Non-Exempt     4101        18-2-S205      Unknown      1/24/2022
#
#            reason
# 0  Transferred in

# %%
transferIns = transferIns.drop(['co_#', 'co_name', 'pr_dept_desc.', 'project', 'craft_class_desc', 'audit_date'], axis=1)

# %%
transferOuts.head(1)
# Out:
#      EE # FLSA Category  PR Dept  Project Code Craft Class Code  \
# 0  274388        Exempt     4101           NaN        18-6-S610
#
#   TransferOutDate           Reason
# 0      05/08/2022  Transferred out

# %%
transferOuts = transferOuts.drop(['PR Dept Desc.', 'Project', 'Craft Class Desc', 'Audit Date'], axis=1)

# %%
demotions[['Date', 'Time']] = demotions['Effective Date'].str.split(' ', expand=True)

# %%
demotions = demotions.drop(['Co #', 'Co Name', 'PR Dept Desc.', 'Project', 'Craft Class Desc', 'Audit Date'], axis=1)

# %%
demotions = demotions.drop(['Effective Date', 'Time'], axis=1)

# %%
demotions['Project Code'] = demotions['Project Code'].astype('Int64')

# %%
demotions = demotions.rename(columns={'Date': 'DemotionDate'})

# %%
allEmp.to_csv('allEmp.csv', index=False)

# %%
newHires.to_csv('newHires.csv', index=False)

# %%
promotions.to_csv('promotions.csv', index=False)

# %%
demotions.to_csv('demotions.csv', index=False)

# %%
rehires.to_csv('rehires.csv', index=False)

# %%
transferIns.to_csv('transferIns.csv', index=False)

# %%
transferOuts.to_csv('transferOuts.csv', index=False)
